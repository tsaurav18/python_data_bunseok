# %%
import pandas as pd
import numpy as np

# %%
import os
import glob
path = './data/'

# csv 파일과 xlsx 파일 리스트 분리
csv = glob.glob(path+'*.csv')

xlsx = glob.glob(path+'*.xlsx')

# 분리된 파일 확인
csv, xlsx
# Out:
# (['./data\\서울특별시 공공자전거 대여정보_201812.csv',
#   './data\\서울특별시 공공자전거 대여정보_201901.csv',
#   './data\\서울특별시 공공자전거 대여정보_201902.csv'],
#  [])

# %%
# 컬럼 이름을 미리 생성
column_name = ['자전거번호', '대여일시', '대여대여소번호', '대여대여소명',
               '거치대순번', '반납일시', '반납대여소번호', '반납대여소명',
               '반납거치대순번', '이용시간', '이용거리']

# %%
# CSV 파일 병합
df = pd.read_csv(csv[0], encoding='cp949')
df.columns = column_name

for file in csv[-3:]:
    df2 = pd.read_csv(file, encoding='cp949')
    df2.columns = column_name
    
    df = pd.concat([df, df2])
df.shape
# Out:
# (1942397, 11)

# %% [markdown]
# ```python
# # XLSX 파일 병합
# for file in xlsx:
#     df2 = pd.read_excel(file)
#     df2.columns = column_name
#
#     df = pd.concat([df, df2])
# df.shape
# ```

# %%
# 병합 파일 저장
df.to_csv('./data/rent_merge.csv', index=False)

# %% [markdown]
# # 데이터 분석

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# 데이터 불러오기
df = pd.read_csv('./data/rent_merge.csv')

# %%
# 데이터 프레임 상위 5개 출력
# Out:
#        자전거번호                 대여일시  대여대여소번호        대여대여소명  거치대순번  \
# 0  SPB-05427  2018-12-01 00:01:03     1113  서남환경공원 버스정류장      1
# 1  SPB-05991  2018-12-01 00:01:46     3100          북성초교      1
# 2  SPB-11186  2018-12-01 00:00:01     1357       북한산보국문역     13
# 3  SPB-02872  2018-12-01 00:01:21     3538      서울숲 IT캐슬      8
# 4  SPB-15780  2018-12-01 00:02:47      245   삼성생명 당산사옥 앞      3
#
#                   반납일시  반납대여소번호         반납대여소명  반납거치대순번  이용시간   이용거리
# 0  2018-12-01 00:04:24     1112    마곡엠밸리4단지 정문        5     3  700.0
# 1  2018-12-01 00:04:34     3104  e편한세상 신촌4단지 앞        4     2  430.0
# 2  2018-12-01 00:04:50     1360            정릉역        1     4  940.0
# 3  2018-12-01 00:04:53      512    뚝섬역 1번 출구 옆        8     3  410.0
# 4  2018-12-01 00:05:25      245    삼성생명 당산사옥 앞        3     2    0.0

# %%
# 데이터 프레임 컬렁 정보 출력
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1942397 entries, 0 to 1942396
# Data columns (total 11 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   자전거번호    object
#  1   대여일시     object
#  2   대여대여소번호  int64
#  3   대여대여소명   object
#  4   거치대순번    int64
#  5   반납일시     object
#  6   반납대여소번호  int64
#  7   반납대여소명   object
#  8   반납거치대순번  int64
#  9   이용시간     int64
#  10  이용거리     float64
# dtypes: float64(1), int64(5), object(5)
# memory usage: 163.0+ MB

# %% [markdown]
# # 데이터 프레임 가공
#
# - 대여 정보(날짜, 시간)와 반납 정보(날짜, 시간)을 분할

# %%
# 시간데이터로 변경
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1942397 entries, 0 to 1942396
# Data columns (total 11 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   자전거번호    object
#  1   대여일시     datetime64[ns]
#  2   대여대여소번호  int64
#  3   대여대여소명   object
#  4   거치대순번    int64
#  5   반납일시     datetime64[ns]
#  6   반납대여소번호  int64
#  7   반납대여소명   object
#  8   반납거치대순번  int64
#  9   이용시간     int64
#  10  이용거리     float64
# dtypes: datetime64[ns](2), float64(1), int64(5), object(3)
# memory usage: 163.0+ MB

# %%
# Out:
#        자전거번호                대여일시  대여대여소번호        대여대여소명  거치대순번  \
# 0  SPB-05427 2018-12-01 00:01:03     1113  서남환경공원 버스정류장      1
# 1  SPB-05991 2018-12-01 00:01:46     3100          북성초교      1
# 2  SPB-11186 2018-12-01 00:00:01     1357       북한산보국문역     13
# 3  SPB-02872 2018-12-01 00:01:21     3538      서울숲 IT캐슬      8
# 4  SPB-15780 2018-12-01 00:02:47      245   삼성생명 당산사옥 앞      3
#
#                  반납일시  반납대여소번호         반납대여소명  반납거치대순번  이용시간   이용거리
# 0 2018-12-01 00:04:24     1112    마곡엠밸리4단지 정문        5     3  700.0
# 1 2018-12-01 00:04:34     3104  e편한세상 신촌4단지 앞        4     2  430.0
# 2 2018-12-01 00:04:50     1360            정릉역        1     4  940.0
# 3 2018-12-01 00:04:53      512    뚝섬역 1번 출구 옆        8     3  410.0
# 4 2018-12-01 00:05:25      245    삼성생명 당산사옥 앞        3     2    0.0

# %%
# Out:
#        자전거번호                대여일시  대여대여소번호        대여대여소명  거치대순번  \
# 0  SPB-05427 2018-12-01 00:01:03     1113  서남환경공원 버스정류장      1
# 1  SPB-05991 2018-12-01 00:01:46     3100          북성초교      1
# 2  SPB-11186 2018-12-01 00:00:01     1357       북한산보국문역     13
# 3  SPB-02872 2018-12-01 00:01:21     3538      서울숲 IT캐슬      8
# 4  SPB-15780 2018-12-01 00:02:47      245   삼성생명 당산사옥 앞      3
#
#                  반납일시  반납대여소번호         반납대여소명  반납거치대순번  이용시간  ...  대여_년  대여_월  \
# 0 2018-12-01 00:04:24     1112    마곡엠밸리4단지 정문        5     3  ...  2018    12
# 1 2018-12-01 00:04:34     3104  e편한세상 신촌4단지 앞        4     2  ...  2018    12
# 2 2018-12-01 00:04:50     1360            정릉역        1     4  ...  2018    12
# 3 2018-12-01 00:04:53      512    뚝섬역 1번 출구 옆        8     3  ...  2018    12
# 4 2018-12-01 00:05:25      245    삼성생명 당산사옥 앞        3     2  ...  2018    12
#
#    대여_일  대여_시  대여_분  반납_년  반납_월  반납_일  반납_시  반납_분
# 0     1     0     1  2018    12     1     0     4
# 1     1     0     1  2018    12     1     0     4
# 2     1     0     0  2018    12     1     0     4
# 3     1     0     1  2018    12     1     0     4
# 4     1     0     2  2018    12     1     0     5
#
# [5 rows x 21 columns]

# %% [markdown]
# # 기초 분석

# %%
# Out:
# 대여_월
# 1     476758
# 2     469725
# 12    995914
# Name: 대여_월, dtype: int64

# %%
# Out:
# 대여_년
# 2018    995914
# 2019    946483
# Name: 대여_년, dtype: int64

# %%
# Out:
# Int64Index([2018, 2019], dtype='int64', name='대여_년')

# %%
# Out:
# 대여_년
# 2018        NaN
# 2019   -49431.0
# dtype: float64

# %% [markdown]
# # 데이터 시각화

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
# Out:
# <AxesSubplot:xlabel='대여_일', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='대여_월', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='대여_년', ylabel='count'>

# %% [markdown]
# # 특정 대여소를 타겟으로 분석

# %%
#등록된 대여소명(대여, 반납) 분석
# Out:
# (3055, 3058)

# %%
# 가장 많이 대여된 대여소명 확인
# Out:
# 대여대여소명
# 홍대입구역 2번출구 앞               5390
# 113. 홍대입구역 2번출구 앞          4528
# 안암로터리 버스정류장 앞              4076
# 롯데월드타워(잠실역2번출구 쪽)          3812
# 1210. 롯데월드타워(잠실역2번출구 쪽)    3581
#                            ...
# 은평 지웰테라스                      6
# 2612. 문정·가락 대여소 앞             5
# 9997.강남센터                     3
# 1687. 서울월드컵경기장 테스트            2
# 9996. 시설2                     2
# Name: 대여대여소명, Length: 3055, dtype: int64

# %%
# 가장 많이 반납된 대여된 대여소명 확인
# Out:
# 반납대여소명
# 홍대입구역 2번출구 앞               7136
# 113. 홍대입구역 2번출구 앞          4528
# 안암로터리 버스정류장 앞              4362
# 롯데월드타워(잠실역2번출구 쪽)          3878
# 1210. 롯데월드타워(잠실역2번출구 쪽)    3581
#                            ...
# 9997.강남센터                     3
# 은평 지웰테라스                      2
# 창동한신                          2
# 9996. 시설2                     2
# 1687. 서울월드컵경기장 테스트            2
# Name: 반납대여소명, Length: 3058, dtype: int64

# %%
# Out:
#           자전거번호                대여일시  대여대여소번호        대여대여소명  거치대순번  \
# 384   SPB-07313 2018-12-01 00:26:50      113  홍대입구역 2번출구 앞      2
# 394   SPB-01083 2018-12-01 00:31:16      113  홍대입구역 2번출구 앞     25
# 1033  SPB-18180 2018-12-01 00:54:00      113  홍대입구역 2번출구 앞      1
# 1384  SPB-07107 2018-12-01 01:16:50      113  홍대입구역 2번출구 앞     18
# 1599  SPB-03724 2018-12-01 01:23:28      113  홍대입구역 2번출구 앞      8
#
#                     반납일시  반납대여소번호      반납대여소명  반납거치대순번  이용시간  ...  대여_년  대여_월  \
# 384  2018-12-01 00:36:27      141   연대 대운동장 옆        5     9  ...  2018    12
# 394  2018-12-01 00:37:10      102  망원역 1번출구 앞        6     5  ...  2018    12
# 1033 2018-12-01 01:14:49      153    성산2교 사거리        3    20  ...  2018    12
# 1384 2018-12-01 01:34:31      166    가재울 초등학교       11    17  ...  2018    12
# 1599 2018-12-01 01:46:11      166    가재울 초등학교       20    22  ...  2018    12
#
#       대여_일  대여_시  대여_분  반납_년  반납_월  반납_일  반납_시  반납_분
# 384      1     0    26  2018    12     1     0    36
# 394      1     0    31  2018    12     1     0    37
# 1033     1     0    54  2018    12     1     1    14
# 1384     1     1    16  2018    12     1     1    34
# 1599     1     1    23  2018    12     1     1    46
#
# [5 rows x 21 columns]

# %%
# Out:
# <AxesSubplot:xlabel='대여_일', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='대여_시', ylabel='count'>

# %%
# Out:
# 자전거번호
# SPB-00201     34
# SPB-00236     52
# SPB-00374     26
# SPB-00442    280
# SPB-00444     14
#             ...
# SPB-20002     30
# SPB-20014     26
# SPB-20015     32
# SPB-20018     44
# SPB-20023    194
# Name: 이용시간, Length: 1531, dtype: int64

# %%
# Out:
# 반납대여소명
# (구)합정동 주민센터       174
# CJ 드림시티           106
# DMC역 2번출구 옆       166
# DMC역 9번출구 앞       116
# DMC첨단산업센터          74
#                 ...
# 홍대입구역 2번출구 앞    13496
# 홍대입구역 8번출구 앞     1700
# 홍연2교옆             910
# 홍은동 정원여중 입구       536
# 홍제삼거리 북측          248
# Name: 이용시간, Length: 161, dtype: int64

# %%
# Out:
# 자전거번호      반납대여소명
# SPB-00201  마포구청역               34
# SPB-00236  가재울 뉴타운 주유소 옆       32
#            서대문소방서              20
# SPB-00374  하늘채코오롱아파트 건너편       26
# SPB-00442  신한은행 서교동금융센터점 앞    280
#                              ...
# SPB-20014  일진아이윌아파트 옆          14
# SPB-20015  연서어린이공원             32
# SPB-20018  가좌역 4번출구 앞          44
# SPB-20023  새절역 2번출구           112
#            신한은행 서교동금융센터점 앞     82
# Name: 이용시간, Length: 2585, dtype: int64

# %%
# Out:
# <AxesSubplot:xlabel='반납대여소명', ylabel='대여_일'>

# %%
# Out:
# <AxesSubplot:xlabel='반납대여소명', ylabel='대여_시'>

# %% [markdown]
# # 특정 자전거를 타겟으로 분석

# %%
# 자전거 번호별 이용시간 분석
# 이를 통해 사용 시간이 오래된 자전거의 사용 패턴을 확인

# %%
# Out:
# 자전거번호
# SPB-18016    15259
# SPB-17451    10816
# SPB-15628    10721
# SPB-00208    10619
# SPB-19639     9389
# SPB-06615     9264
# SPB-19739     8974
# SPB-19036     8752
# SPB-15588     8527
# SPB-19926     8400
# Name: 이용시간, dtype: int64

# %%
# 자전거(SPB18016)의 대여소 확인
# Out:
# (92, 91)

# %%
# 자전거(SPB18016)의 대여소별 건수 확인
# Out:
# 동대문역 8번 출구           6
# 군자역 7번출구 베스트샵 앞      6
# 세종사이버대학교             6
# 성동세무서 건너편            4
# 양재시민의숲역 3번출구         4
#                     ..
# 926. 불광역 8번출구        1
# 951. 연신내역 6번출구옆      1
# 1112. 마곡엠밸리4단지 정문    1
# 841. 신용산역 1번 출구      1
# 1163. 방화동강서기동대앞      1
# Name: 대여대여소명, Length: 92, dtype: int64

# %%
# Out:
# 군자역 7번출구 베스트샵 앞        6
# 동대문역 8번 출구             6
# 세종사이버대학교               6
# 446. 상명대입구             4
# 양재시민의숲역 3번출구           4
#                       ..
# 834. 효창공원앞역 3번출구 뒤     1
# 1151. 마곡역1번출구          1
# 1114. 서남물재생센터 버스정류장    1
# 954. 은평뉴타운구파발9단지       1
# 411. DMC홍보관            1
# Name: 반납대여소명, Length: 91, dtype: int64

# %%
# Out:
# <AxesSubplot:xlabel='대여_일', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='대여_시', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='대여_월', ylabel='count'>

# %%
# Out:
# <AxesSubplot:xlabel='반납대여소명', ylabel='대여_일'>

# %%
# Out:
# <AxesSubplot:xlabel='반납대여소명', ylabel='대여_월'>

# %%
# Out:
# <AxesSubplot:xlabel='반납대여소명', ylabel='대여_시'>

# %% [markdown]
# # 대여소 위치 시각화

# %%
# Out:
#     구분  대여소번호              대여소명         위도          경도  거치대수
# 0  마포구    101  101. (구)합정동 주민센터  37.549561  126.905754     5
# 1  마포구    102   102. 망원역 1번출구 앞  37.556000  126.910454    20
# 2  마포구    103   103. 망원역 2번출구 앞  37.554951  126.910835    14
# 3  마포구    104   104. 합정역 1번출구 앞  37.550629  126.914986    13
# 4  마포구    105   105. 합정역 5번출구 앞  37.550007  126.914825     5

# %%
import folium

# 자전거 거치대의 평균값을 지도의 중심값으로설정
m = folium.Map(location=[station['위도'].mean(), station['경도'].mean()], zoom_strat=12)

for n in station.index:
    folium.Circle(
        location=[station.loc[n, '위도'], station.loc[n, '경도']],
        popup=station.loc[n, '대여소명'],
        radius=10,
        color='blue',
        fill=True,
        fill_color='blue'
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_999b1cbacdad47afbf1fed159ea494c8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_999b1cbacdad47afbf1fed159ea494c8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_999b1cbacdad47afbf1fed159ea494c8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_999b1cbacdad47afbf1fed159ea494c8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.54761560507488%2C%20126.99084812882244%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Out:
#       count
# 구분
# 강남구     100
# 송파구      99
# 영등포구     89
# 서초구      87
# 강서구      86
# 마포구      78
# 노원구      67
# 종로구      64
# 성동구      63
# 은평구      62
# 구로구      61
# 광진구      60
# 강동구      58
# 성북구      58
# 서대문구     54
# 양천구      54
# 관악구      52
# 중랑구      52
# 동대문구     51
# 금천구      44
# 중구       44
# 동작구      41
# 강북구      39
# 용산구      39
# 도봉구      35

# %%
# Out:
# <AxesSubplot:xlabel='구분', ylabel='count'>

# %%
# Out:
#        sum
# 구분
# 송파구   1279
# 영등포구  1258
# 서초구   1214
# 강남구   1210
# 마포구   1062

# %%
# Out:
# <AxesSubplot:xlabel='구분', ylabel='sum'>
